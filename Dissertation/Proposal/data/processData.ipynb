# %%
import pandas as pd

# %%
file_path = "./1824301624.csv"

df = pd.read_csv(file_path, encoding="utf-8", header=0)

pd.set_option("display.max_colwidth", None)

# %%
column = df['微博正文']

# %%
filtered_df = df[df["微博正文"].str.contains(("爱丁堡" or "爱宝"))]

# %%
filtered_df.shape
# Out:
# (570, 11)

# %%
filtered_df
# Out:
#            微博id  \
# 0     LxQkeiPl3
# 10    O27YpgS0b
# 19    O27SBxfPR
# 20    O27PYCIWj
# 35    O1UIYeRGC
# ...         ...
# 6522  KwviPywxk
# 6528  KwsOAstZ9
# 6543  KwlKe0mvc
# 6545  KwltZ2xEQ
# 6562  Kw9Lq8N3p
#
#                                                                                                                                                                                                                                                                   微博正文  \
# 0                                                                                           [置顶]【Cook留学答疑说明】欢迎私信我Offer信息，和申请干货信息，感谢所有投稿者！我微博的内容：英国+澳洲+中国香港+新加坡+欧陆学校申请，老地图，老照片，长沙历史留学申请报名：网页链接英国：（纯G5申请建议DIY是更好的)11000元申5所（不含G5，KCL，爱丁堡，曼大，华威申请）13000...全文 [组图共11张] 原图
# ...
