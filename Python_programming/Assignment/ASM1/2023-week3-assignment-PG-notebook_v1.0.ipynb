# %%
# experimental: you can run this cell to see your code full-width
from IPython.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # Python Programming - Pair Assignment - Week 3
#
# ### This is your assignment notebook.
#
# In this notebook you and your partner will write your pair assignment. Steps for submitting the assignment will be described on Learn.
#
# ### How to edit a notebook that has more than code:
#
# In this notebook you can see there are:
#
# - **code cells** - in these you can edit and run python code
# - **markdown cells** - basically text cells, like the one you are reading now. When you are done editing them, 'Run' them as you would run your python code to make them pretty. They use the 'Markdown' text formatting language, so eg. starting a line with # or ## will make it a header, and surroounding something with two asterixes ** will make it bold
#
# Double-click this cell to see how you can edit a markdown cell and then Run it with Shift+Enter to see it 'interpreted' into headers and styled text.
#
# - To change a type of cell, use dropdown in the menu on top.
# - remember to save your work frequently with usual keyboard shortcut, or File > Save & Checkpoint
#
# small notes:
#
# - please do not rename the notebook file.
# - use **+** plus icon in the menu to add new cells

# %% [markdown]
# # Your Week 3 assignment task is:
#
# Imagine you are a junior data analyst working for an organisation who uses this data (NHS, Government, Tesco, Train company). Your job is to identify and present some insights from the data - to ask, and then answer a question relevant to this business (aka. 'a business question'). Look at the data - what type of questions can they answer?
#
# 1. Explore the data using code
# 2. Formulate and answer a business question (using the data)
# 3. Describe what you found using 200 words and ONE graph.
#
# The question does not need to be complicated. The analysis does not need to be complicated - simple descriptives and visualisations are good enough! Your task is to use python to operate on data, find answer and support it with a graph or well-crafted table.

# %% [markdown]
# # Extra Challenge: "Look Ma! No Pandas!" 🚫🐼
#
# First 3 weeks of the course are dedicated to you making sure you have mastered the foundations of python as a programming language.
#
# That's why we want to give you all a chance to really confirm that you know basic python:
#
# **to get more than 70% in this assignment you need to use pure python (without Panda/Numpy)** in this assignment.
#
# This will give you a chance to really practice functions, list comprehensions, dictionaries, list, loops, lambdas etc.
#
# From week 4 onwards we will be working a lot on Pandas but you first need to learn the basics.

# %% [markdown]
# ### Deliverable:
#
# 1. In this notebook please include all the code that you used to arrive at the conclusion.
# 2. At the end of your notebook, you should also provide your 'mini-report':
#
# - a markdown (text) cell with your mini-report (200 words +/- 10%). For reference, 'Marking criteria' section below has around 220 words)
# - a cell which will generate the graph or table that accompanies your mini-report (you are allowed to combine number of graphs, if they are combined into one unit and make sense, eg. combining 3 bar charts side by side, or overlapping a line chart with a bar chart).
# - any visualisation library is allowed, but for your own learning, try to use a few different ones during the course.

# %% [markdown]
# ### Marks:
#
# You will get points in university marking system for each of the below categories.
#
# 0- 50% : Unsafisfactory
#
# 50-60% : Good
#
# 60-70% : Very Good
#
# 70% +  : Excellent
#
# **Definition of 'Excellent': Text, graph and code that you would be proud to share on your LinkedIn, for your future employers to see.**

# %% [markdown]
# Your grade will be the average of your points in all below categories. This assignment is worth 10% of your grade for this course. You and your partner will get the same grade. Only ONE of you should submit the assignment.
#
# ### Marking Criteria:
#
# **A) Business Question and Answer:** Did you manage to find a question that can be answered with given data? As an analyst you will often have to dive into available data and identify how it ccan help the business, or solve a problem, withou first knowing what the problem is. Also can you formulate a clear answer to the question you created?
#
# **B) Using the Data:** How well did you use the data to answer your question? Your answer should be supported by what you found in the data. Briefly describe why this was the correct data, and correct analysis to perform on it.
#
# **C) Visualisation:** Can you aid your argument/aswer with visual clues? Graph can say a thousand words, but it is also easy to make one which is confusing, or misleading. Use simple (or highly customised) graphs to make your argument clearer.
#
# **D) Code Quality:** Is your code clean, readable and DRY (Don't repeat yourself)? Are you using good readable variable names? Did you clean up your code and does it not include enay old/unused parts?
#
# **E) Code Structure:** Is your code well structured and broken down? Just like good writing has sentences, paragraphs and chapters, good code should be split into sections. Breakdown your code into cells and functions. Use meaningful signposts (eg. comments, function names) to guide the reader through your code.
#
#
# ### Difficulty:
#
# This assignment should not take you and your partner more than 1-2h. There are not extra points for making the question DIFFICULT, but you are graded for CLEAN CODE and COMMUNICATING clearly.

# %% [markdown]
# # Task:
#
# ### For ginen datasets try to identify one interesting question that data could answer. Then write python code that finds answer to that question, and describe your findings in a visualisation and a few sentences.
#
#
# **1. look at the data.**
#
# are they in formats that you might need? (numbers, strings, dates, etc). Remember that you can change variables with data (eg. add new key-value pairs)
#
# **2. what are the questions this data could answer?**
#
# you are given an example questions, but if you want to pursue different questions, feel free to do that!
#
# **3. write code to extract some meaningful information from this data**
#
# make your code as meaningful as possible. make sure your variables and functions are meaningful.
#
# **4. visualise what you found.**
#
# this could be a simple graph, or a printed sentence or table
#
# **5. write a very short, two-sentence synopsis of what you found**
#
# What question you asked? What is the answer? What could it mean?

# %% [markdown]
# # FAQ:
#
# ⚠️ You can use one or more datasets that you were given. Only add additional datasets if they someohow compliement the ones you were given (eg. to position the NHS boards on a map)
#
# ⚠️ In your notebook you will explore the data and play around a bit. But you will be marked on the quality of all of your code, so make sure you clean up things you ended up not using.
#
# ⚠️ Often during exploration people produce very many graphs, and that's ok. This graphs will NOT be marked. At the end PICK ONE GRAPH which accompanies your written mini-report best, and make sure it is included in a clear way with yoru writeup. If it will be unclear which graph is your picked one, we will mark a last one we see and ignore everything else.
#
# ⚠️ Your writeup has a very strict word limit. It is ok to write text and comments amongst your code, but they will not count towards your writeup mark, or your writeup wordcount.
#
# ⚠️ Easiest way to do well on this assignment is:
#
# - use meaningul variable/function names.
# - structure your code well in cells and functions
# - write a mini-report where things are backed by the analysis you ran with your code (i.e. are not just personal opinions, or known facts).
#
# Good luck!

# %%
# starting code:

# %%
# the usual imports
import pprint as pp
import json

# %%
# starting code that loads data, run this cell, but no need to understand it in depth
# this function just loads the data from files
def load_json_file_named(file_name):
    try: 
        loaded_data = []
        file_location = f"data/{file_name}"
        with open(file_location, 'r') as file: # or f"data/{file_name}" depending on your files
            loaded_data =  json.load(file)
    except OSError as e:
        print(f"Error. Does the file exist in this folder? {file_location}\n\n {e}")
    return loaded_data

# %%
boards_info = load_json_file_named('nhs_scotland_boards.json')
covid_days = load_json_file_named('covid_records_scotland.json')
cancer_waiting_times = load_json_file_named('cancer_waiting_times.json')
boards_code_lookup = load_json_file_named('boards_code_lookup.json')

# %% [markdown]
# # Datasets:
#
# You are given 4 datasets, described below:
#
# - boards_info
# - covid_days
# - cancer_waiting_times
# - boards_code_lookup

# %% [markdown]
# ### First and Second Dataset: NHS boards and Covid days
#
# You probably already know this dataset. It consists of two variables:
#
# - boards_info contains information about nhs boards
# - covid_days contains information patients in the first 2 years of covid pandemic
#
# Look at the data, and ask yourself: what data-driven insights can we get from it? Come up with your own question, or get inspired by the ones below:
#
# Does covid spread more in densely populated areas? Look at NHS boards' population density and number of covid-related deaths in those boards. Maybe also look at:
#
# - number of deaths
# - deaths per person who lives in that board
# - or deaths per infection

# %%
# this is how data looks like:
pp.pprint(boards_info[0])
# Out:
# {'budget_millions': {'2020': 762, '2021': 775, '2022': 807},
#  'geographic': {'area_km_2': 2924,
#                 'areas_covered': 'East Ayrshire, North Ayrshire, South '
#                                  'Ayrshire'},
#  'name': 'NHS Ayrshire and Arran',
#  'people': {'patients': 369670, 'staff': 9491}}

# %%
# example of what you could do
budgets_21 = [
    board['budget_millions']['2021']
    for board in boards_info
]
print(sum(budgets_21))
# Out:
# 10586

# %%
# this is how data looks like:
pp.pprint(covid_days[10])
# Out:
# {'date': 20200309,
#  'locations': {'NHS Ayrshire and Arran': {'first_infections': 1,
#                                           'new_deaths': 0,
#                                           'new_positive': 1,
#                                           'reinfections': 0},
#                'NHS Borders': {'first_infections': 1,
#                                'new_deaths': 0,
#                                'new_positive': 1,
#                                'reinfections': 0},
#                'NHS Dumfries and Galloway': {},
#                'NHS Fife': {'first_infections': 1,
#                             'new_deaths': 0,
#                             'new_positive': 1,
#                             'reinfections': 0},
#                'NHS Forth Valley': {'first_infections': 0,
#                                     'new_deaths': 0,
#                                     'new_positive': 0,
#                                     'reinfections': 0},
#                'NHS Grampian': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                'NHS Greater Glasgow and Clyde': {'first_infections': 3,
#                                                  'new_deaths': 0,
#                                                  'new_positive': 3,
#                                                  'reinfections': 0},
#                'NHS Highland': {},
#                'NHS Lanarkshire': {'first_infections': 0,
#                                    'new_deaths': 0,
#                                    'new_positive': 0,
#                                    'reinfections': 0},
#                'NHS Lothian': {'first_infections': 3,
#                                'new_deaths': 0,
#                                'new_positive': 3,
#                                'reinfections': 0},
#                'NHS Orkney': {},
#                'NHS Shetland': {'first_infections': 4,
#                                 'new_deaths': 0,
#                                 'new_positive': 4,
#                                 'reinfections': 0},
#                'NHS Tayside': {'first_infections': 3,
#                                'new_deaths': 0,
#                                'new_positive': 3,
#                                'reinfections': 0},
#                'NHS Western Isles': {}},
#  'whole_scotland': {'first_infections': 16,
#                     'new_deaths': 0,
#                     'new_positive': 16,
#                     'reinfections': 0}}

# %%
# IMPORTANT: keep in mind that not all days include all keys
# so this is fine:
pp.pprint(covid_days[10]['locations']['NHS Lanarkshire']['first_infections'])

# but this will crash! look at the error, and data above and guess why
pp.pprint(covid_days[10]['locations']['NHS Highland']['first_infections'])
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\redhawc\Desktop\EDI_BUSANA\Python_programming\Assignment\ASM1\2023-week3-assignment-PG-notebook_v1.0.ipynb Cell 19 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/redhawc/Desktop/EDI_BUSANA/Python_programming/Assignment/ASM1/2023-week3-assignment-PG-notebook_v1.0.ipynb#X24sZmlsZQ%3D%3D?line=2'>3</a> pp.pprint(covid_days[10]['locations']['NHS Lanarkshire']['first_infections'])
#       <a href='vscode-notebook-cell:/c%3A/Users/redhawc/Desktop/EDI_BUSANA/Python_programming/Assignment/ASM1/2023-week3-assignment-PG-notebook_v1.0.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a> # but this will crash! look at the error, and data above and guess why
# ----> <a href='vscode-notebook-cell:/c%3A/Users/redhawc/Desktop/EDI_BUSANA/Python_programming/Assignment/ASM1/2023-week3-assignment-PG-notebook_v1.0.ipynb#X24sZmlsZQ%3D%3D?line=5'>6</a> pp.pprint(covid_days[10]['locations']['NHS Highland']['first_infections'])
#
# KeyError: 'first_infections'

# %%
# so you'll need to use default values, like this:
pp.pprint(covid_days[10]['locations']['NHS Highland'].get('first_infections', 0))
# Out:
# 0

# %%
pp.pprint(boards_info[0]) 


# pp.pprint(cancer_waiting_times[0].keys())
# Out:
# {'budget_millions': {'2020': 762, '2021': 775, '2022': 807},
#  'geographic': {'area_km_2': 2924,
#                 'areas_covered': 'East Ayrshire, North Ayrshire, South '
#                                  'Ayrshire'},
#  'name': 'NHS Ayrshire and Arran',
#  'people': {'patients': 369670, 'staff': 9491}}

# %%
pp.pprint(covid_days) 
'''
 'name': 'NHS Ayrshire and Arran',
 'people': {'patients': 369670, 'staff': 9491}}
 --------------------------
 'date': ALL,
 'locations':'NHS Ayrshire and Arran',

'''
# Out:
# [{'date': 20200228,
#   'locations': {'NHS Ayrshire and Arran': {},
#                 'NHS Borders': {},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {},
#                 'NHS Forth Valley': {},
#                 'NHS Grampian': {},
#                 'NHS Greater Glasgow and Clyde': {},
#                 'NHS Highland': {},
#                 'NHS Lanarkshire': {},
#                 'NHS Lothian': {},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {},
#                 'NHS Tayside': {'first_infections': 1,
#                                 'new_deaths': 0,
#                                 'new_positive': 1,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 1,
#                      'new_deaths': 0,
#                      'new_positive': 1,
#                      'reinfections': 0}},
#  {'date': 20200229,
#   'locations': {'NHS Ayrshire and Arran': {},
#                 'NHS Borders': {},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {},
#                 'NHS Forth Valley': {},
#                 'NHS Grampian': {},
#                 'NHS Greater Glasgow and Clyde': {},
#                 'NHS Highland': {},
#                 'NHS Lanarkshire': {},
#                 'NHS Lothian': {},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {},
#                 'NHS Tayside': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 0,
#                      'new_deaths': 0,
#                      'new_positive': 0,
#                      'reinfections': 0}},
#  {'date': 20200301,
#   'locations': {'NHS Ayrshire and Arran': {},
#                 'NHS Borders': {},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {},
#                 'NHS Forth Valley': {'first_infections': 1,
#                                      'new_deaths': 0,
#                                      'new_positive': 1,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 1,
#                                  'new_deaths': 0,
#                                  'new_positive': 1,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {},
#                 'NHS Highland': {},
#                 'NHS Lanarkshire': {},
#                 'NHS Lothian': {},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {},
#                 'NHS Tayside': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 2,
#                      'new_deaths': 0,
#                      'new_positive': 2,
#                      'reinfections': 0}},
#  {'date': 20200302,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 1,
#                                            'new_deaths': 0,
#                                            'new_positive': 1,
#                                            'reinfections': 0},
#                 'NHS Borders': {},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {},
#                 'NHS Forth Valley': {'first_infections': 0,
#                                      'new_deaths': 0,
#                                      'new_positive': 0,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {},
#                 'NHS Highland': {},
#                 'NHS Lanarkshire': {},
#                 'NHS Lothian': {},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {},
#                 'NHS Tayside': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 1,
#                      'new_deaths': 0,
#                      'new_positive': 1,
#                      'reinfections': 0}},
#  {'date': 20200303,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 0,
#                                            'new_deaths': 0,
#                                            'new_positive': 0,
#                                            'reinfections': 0},
#                 'NHS Borders': {},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {},
#                 'NHS Forth Valley': {'first_infections': 1,
#                                      'new_deaths': 0,
#                                      'new_positive': 1,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 1,
#                                  'new_deaths': 0,
#                                  'new_positive': 1,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 1,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 1,
#                                                   'reinfections': 0},
#                 'NHS Highland': {},
#                 'NHS Lanarkshire': {},
#                 'NHS Lothian': {},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {},
#                 'NHS Tayside': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 3,
#                      'new_deaths': 0,
#                      'new_positive': 3,
#                      'reinfections': 0}},
#  {'date': 20200304,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 0,
#                                            'new_deaths': 0,
#                                            'new_positive': 0,
#                                            'reinfections': 0},
#                 'NHS Borders': {},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {'first_infections': 2,
#                              'new_deaths': 0,
#                              'new_positive': 2,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 1,
#                                      'new_deaths': 0,
#                                      'new_positive': 1,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 2,
#                                  'new_deaths': 0,
#                                  'new_positive': 2,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 0,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 0,
#                                                   'reinfections': 0},
#                 'NHS Highland': {},
#                 'NHS Lanarkshire': {},
#                 'NHS Lothian': {'first_infections': 1,
#                                 'new_deaths': 0,
#                                 'new_positive': 1,
#                                 'reinfections': 0},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {},
#                 'NHS Tayside': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 6,
#                      'new_deaths': 0,
#                      'new_positive': 6,
#                      'reinfections': 0}},
#  {'date': 20200305,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 0,
#                                            'new_deaths': 0,
#                                            'new_positive': 0,
#                                            'reinfections': 0},
#                 'NHS Borders': {},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {'first_infections': 0,
#                              'new_deaths': 0,
#                              'new_positive': 0,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 0,
#                                      'new_deaths': 0,
#                                      'new_positive': 0,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 1,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 1,
#                                                   'reinfections': 0},
#                 'NHS Highland': {},
#                 'NHS Lanarkshire': {'first_infections': 1,
#                                     'new_deaths': 0,
#                                     'new_positive': 1,
#                                     'reinfections': 0},
#                 'NHS Lothian': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {},
#                 'NHS Tayside': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 2,
#                      'new_deaths': 0,
#                      'new_positive': 2,
#                      'reinfections': 0}},
#  {'date': 20200306,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 0,
#                                            'new_deaths': 0,
#                                            'new_positive': 0,
#                                            'reinfections': 0},
#                 'NHS Borders': {},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {'first_infections': 0,
#                              'new_deaths': 0,
#                              'new_positive': 0,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 0,
#                                      'new_deaths': 0,
#                                      'new_positive': 0,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 1,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 1,
#                                                   'reinfections': 0},
#                 'NHS Highland': {},
#                 'NHS Lanarkshire': {'first_infections': 1,
#                                     'new_deaths': 0,
#                                     'new_positive': 1,
#                                     'reinfections': 0},
#                 'NHS Lothian': {'first_infections': 2,
#                                 'new_deaths': 0,
#                                 'new_positive': 2,
#                                 'reinfections': 0},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {'first_infections': 2,
#                                  'new_deaths': 0,
#                                  'new_positive': 2,
#                                  'reinfections': 0},
#                 'NHS Tayside': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 6,
#                      'new_deaths': 0,
#                      'new_positive': 6,
#                      'reinfections': 0}},
#  {'date': 20200307,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 1,
#                                            'new_deaths': 0,
#                                            'new_positive': 1,
#                                            'reinfections': 0},
#                 'NHS Borders': {},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {'first_infections': 0,
#                              'new_deaths': 0,
#                              'new_positive': 0,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 0,
#                                      'new_deaths': 0,
#                                      'new_positive': 0,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 2,
#                                  'new_deaths': 0,
#                                  'new_positive': 2,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 0,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 0,
#                                                   'reinfections': 0},
#                 'NHS Highland': {},
#                 'NHS Lanarkshire': {'first_infections': 1,
#                                     'new_deaths': 0,
#                                     'new_positive': 1,
#                                     'reinfections': 0},
#                 'NHS Lothian': {'first_infections': 2,
#                                 'new_deaths': 0,
#                                 'new_positive': 2,
#                                 'reinfections': 0},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Tayside': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 6,
#                      'new_deaths': 0,
#                      'new_positive': 6,
#                      'reinfections': 0}},
#  {'date': 20200308,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 0,
#                                            'new_deaths': 0,
#                                            'new_positive': 0,
#                                            'reinfections': 0},
#                 'NHS Borders': {},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {'first_infections': 0,
#                              'new_deaths': 0,
#                              'new_positive': 0,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 0,
#                                      'new_deaths': 0,
#                                      'new_positive': 0,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 1,
#                                  'new_deaths': 0,
#                                  'new_positive': 1,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 0,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 0,
#                                                   'reinfections': 0},
#                 'NHS Highland': {},
#                 'NHS Lanarkshire': {'first_infections': 0,
#                                     'new_deaths': 0,
#                                     'new_positive': 0,
#                                     'reinfections': 0},
#                 'NHS Lothian': {'first_infections': 2,
#                                 'new_deaths': 0,
#                                 'new_positive': 2,
#                                 'reinfections': 0},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Tayside': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 3,
#                      'new_deaths': 0,
#                      'new_positive': 3,
#                      'reinfections': 0}},
#  {'date': 20200309,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 1,
#                                            'new_deaths': 0,
#                                            'new_positive': 1,
#                                            'reinfections': 0},
#                 'NHS Borders': {'first_infections': 1,
#                                 'new_deaths': 0,
#                                 'new_positive': 1,
#                                 'reinfections': 0},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {'first_infections': 1,
#                              'new_deaths': 0,
#                              'new_positive': 1,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 0,
#                                      'new_deaths': 0,
#                                      'new_positive': 0,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 3,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 3,
#                                                   'reinfections': 0},
#                 'NHS Highland': {},
#                 'NHS Lanarkshire': {'first_infections': 0,
#                                     'new_deaths': 0,
#                                     'new_positive': 0,
#                                     'reinfections': 0},
#                 'NHS Lothian': {'first_infections': 3,
#                                 'new_deaths': 0,
#                                 'new_positive': 3,
#                                 'reinfections': 0},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {'first_infections': 4,
#                                  'new_deaths': 0,
#                                  'new_positive': 4,
#                                  'reinfections': 0},
#                 'NHS Tayside': {'first_infections': 3,
#                                 'new_deaths': 0,
#                                 'new_positive': 3,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 16,
#                      'new_deaths': 0,
#                      'new_positive': 16,
#                      'reinfections': 0}},
#  {'date': 20200310,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 1,
#                                            'new_deaths': 0,
#                                            'new_positive': 1,
#                                            'reinfections': 0},
#                 'NHS Borders': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {'first_infections': 0,
#                              'new_deaths': 0,
#                              'new_positive': 0,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 5,
#                                      'new_deaths': 0,
#                                      'new_positive': 5,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 1,
#                                  'new_deaths': 0,
#                                  'new_positive': 1,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 5,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 5,
#                                                   'reinfections': 0},
#                 'NHS Highland': {'first_infections': 1,
#                                  'new_deaths': 0,
#                                  'new_positive': 1,
#                                  'reinfections': 0},
#                 'NHS Lanarkshire': {'first_infections': 1,
#                                     'new_deaths': 0,
#                                     'new_positive': 1,
#                                     'reinfections': 0},
#                 'NHS Lothian': {'first_infections': 2,
#                                 'new_deaths': 0,
#                                 'new_positive': 2,
#                                 'reinfections': 0},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {'first_infections': 5,
#                                  'new_deaths': 0,
#                                  'new_positive': 5,
#                                  'reinfections': 0},
#                 'NHS Tayside': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 21,
#                      'new_deaths': 0,
#                      'new_positive': 21,
#                      'reinfections': 0}},
#  {'date': 20200311,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 0,
#                                            'new_deaths': 0,
#                                            'new_positive': 0,
#                                            'reinfections': 0},
#                 'NHS Borders': {'first_infections': 1,
#                                 'new_deaths': 0,
#                                 'new_positive': 1,
#                                 'reinfections': 0},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {'first_infections': 1,
#                              'new_deaths': 0,
#                              'new_positive': 1,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 0,
#                                      'new_deaths': 0,
#                                      'new_positive': 0,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 11,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 11,
#                                                   'reinfections': 0},
#                 'NHS Highland': {'first_infections': 1,
#                                  'new_deaths': 0,
#                                  'new_positive': 1,
#                                  'reinfections': 0},
#                 'NHS Lanarkshire': {'first_infections': 5,
#                                     'new_deaths': 0,
#                                     'new_positive': 5,
#                                     'reinfections': 0},
#                 'NHS Lothian': {'first_infections': 6,
#                                 'new_deaths': 0,
#                                 'new_positive': 6,
#                                 'reinfections': 0},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Tayside': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 25,
#                      'new_deaths': 0,
#                      'new_positive': 25,
#                      'reinfections': 0}},
#  {'date': 20200312,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 3,
#                                            'new_deaths': 0,
#                                            'new_positive': 3,
#                                            'reinfections': 0},
#                 'NHS Borders': {'first_infections': 2,
#                                 'new_deaths': 0,
#                                 'new_positive': 2,
#                                 'reinfections': 0},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {'first_infections': 4,
#                              'new_deaths': 0,
#                              'new_positive': 4,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 0,
#                                      'new_deaths': 0,
#                                      'new_positive': 0,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 5,
#                                  'new_deaths': 0,
#                                  'new_positive': 5,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 10,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 10,
#                                                   'reinfections': 0},
#                 'NHS Highland': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Lanarkshire': {'first_infections': 0,
#                                     'new_deaths': 0,
#                                     'new_positive': 0,
#                                     'reinfections': 0},
#                 'NHS Lothian': {'first_infections': 5,
#                                 'new_deaths': 1,
#                                 'new_positive': 5,
#                                 'reinfections': 0},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Tayside': {'first_infections': 9,
#                                 'new_deaths': 0,
#                                 'new_positive': 9,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 38,
#                      'new_deaths': 1,
#                      'new_positive': 38,
#                      'reinfections': 0}},
#  {'date': 20200313,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 1,
#                                            'new_deaths': 0,
#                                            'new_positive': 1,
#                                            'reinfections': 0},
#                 'NHS Borders': {'first_infections': 1,
#                                 'new_deaths': 0,
#                                 'new_positive': 1,
#                                 'reinfections': 0},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {'first_infections': 1,
#                              'new_deaths': 0,
#                              'new_positive': 1,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 3,
#                                      'new_deaths': 0,
#                                      'new_positive': 3,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 3,
#                                  'new_deaths': 0,
#                                  'new_positive': 3,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 11,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 11,
#                                                   'reinfections': 0},
#                 'NHS Highland': {'first_infections': 4,
#                                  'new_deaths': 0,
#                                  'new_positive': 4,
#                                  'reinfections': 0},
#                 'NHS Lanarkshire': {'first_infections': 8,
#                                     'new_deaths': 0,
#                                     'new_positive': 8,
#                                     'reinfections': 0},
#                 'NHS Lothian': {'first_infections': 3,
#                                 'new_deaths': 0,
#                                 'new_positive': 3,
#                                 'reinfections': 0},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {'first_infections': 11,
#                                  'new_deaths': 0,
#                                  'new_positive': 11,
#                                  'reinfections': 0},
#                 'NHS Tayside': {'first_infections': 2,
#                                 'new_deaths': 0,
#                                 'new_positive': 2,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 48,
#                      'new_deaths': 0,
#                      'new_positive': 48,
#                      'reinfections': 0}},
#  {'date': 20200314,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 0,
#                                            'new_deaths': 0,
#                                            'new_positive': 0,
#                                            'reinfections': 0},
#                 'NHS Borders': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Dumfries and Galloway': {},
#                 'NHS Fife': {'first_infections': 0,
#                              'new_deaths': 0,
#                              'new_positive': 0,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 4,
#                                      'new_deaths': 0,
#                                      'new_positive': 4,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 5,
#                                                   'new_deaths': 2,
#                                                   'new_positive': 5,
#                                                   'reinfections': 0},
#                 'NHS Highland': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Lanarkshire': {'first_infections': 4,
#                                     'new_deaths': 0,
#                                     'new_positive': 4,
#                                     'reinfections': 0},
#                 'NHS Lothian': {'first_infections': 3,
#                                 'new_deaths': 0,
#                                 'new_positive': 3,
#                                 'reinfections': 0},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {'first_infections': 2,
#                                  'new_deaths': 0,
#                                  'new_positive': 2,
#                                  'reinfections': 0},
#                 'NHS Tayside': {'first_infections': 1,
#                                 'new_deaths': 0,
#                                 'new_positive': 1,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 19,
#                      'new_deaths': 2,
#                      'new_positive': 19,
#                      'reinfections': 0}},
#  {'date': 20200315,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 1,
#                                            'new_deaths': 0,
#                                            'new_positive': 1,
#                                            'reinfections': 0},
#                 'NHS Borders': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Dumfries and Galloway': {'first_infections': 1,
#                                               'new_deaths': 0,
#                                               'new_positive': 1,
#                                               'reinfections': 0},
#                 'NHS Fife': {'first_infections': 2,
#                              'new_deaths': 0,
#                              'new_positive': 2,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 2,
#                                      'new_deaths': 0,
#                                      'new_positive': 2,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 1,
#                                  'new_deaths': 0,
#                                  'new_positive': 1,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 1,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 1,
#                                                   'reinfections': 0},
#                 'NHS Highland': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Lanarkshire': {'first_infections': 0,
#                                     'new_deaths': 0,
#                                     'new_positive': 0,
#                                     'reinfections': 0},
#                 'NHS Lothian': {'first_infections': 2,
#                                 'new_deaths': 0,
#                                 'new_positive': 2,
#                                 'reinfections': 0},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Tayside': {'first_infections': 2,
#                                 'new_deaths': 0,
#                                 'new_positive': 2,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 12,
#                      'new_deaths': 0,
#                      'new_positive': 12,
#                      'reinfections': 0}},
#  {'date': 20200316,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 2,
#                                            'new_deaths': 0,
#                                            'new_positive': 2,
#                                            'reinfections': 0},
#                 'NHS Borders': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Dumfries and Galloway': {'first_infections': 2,
#                                               'new_deaths': 0,
#                                               'new_positive': 2,
#                                               'reinfections': 0},
#                 'NHS Fife': {'first_infections': 0,
#                              'new_deaths': 0,
#                              'new_positive': 0,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 1,
#                                      'new_deaths': 0,
#                                      'new_positive': 1,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 8,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 8,
#                                                   'reinfections': 0},
#                 'NHS Highland': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Lanarkshire': {'first_infections': 5,
#                                     'new_deaths': 0,
#                                     'new_positive': 5,
#                                     'reinfections': 0},
#                 'NHS Lothian': {'first_infections': 1,
#                                 'new_deaths': 1,
#                                 'new_positive': 1,
#                                 'reinfections': 0},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Tayside': {'first_infections': 2,
#                                 'new_deaths': 0,
#                                 'new_positive': 2,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 21,
#                      'new_deaths': 1,
#                      'new_positive': 21,
#                      'reinfections': 0}},
#  {'date': 20200317,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 5,
#                                            'new_deaths': 1,
#                                            'new_positive': 5,
#                                            'reinfections': 0},
#                 'NHS Borders': {'first_infections': 0,
#                                 'new_deaths': 0,
#                                 'new_positive': 0,
#                                 'reinfections': 0},
#                 'NHS Dumfries and Galloway': {'first_infections': 3,
#                                               'new_deaths': 0,
#                                               'new_positive': 3,
#                                               'reinfections': 0},
#                 'NHS Fife': {'first_infections': 1,
#                              'new_deaths': 0,
#                              'new_positive': 1,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 3,
#                                      'new_deaths': 0,
#                                      'new_positive': 3,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 2,
#                                  'new_deaths': 0,
#                                  'new_positive': 2,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 13,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 13,
#                                                   'reinfections': 0},
#                 'NHS Highland': {'first_infections': 1,
#                                  'new_deaths': 0,
#                                  'new_positive': 1,
#                                  'reinfections': 0},
#                 'NHS Lanarkshire': {'first_infections': 7,
#                                     'new_deaths': 1,
#                                     'new_positive': 7,
#                                     'reinfections': 0},
#                 'NHS Lothian': {'first_infections': 5,
#                                 'new_deaths': 0,
#                                 'new_positive': 5,
#                                 'reinfections': 0},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Tayside': {'first_infections': 3,
#                                 'new_deaths': 0,
#                                 'new_positive': 3,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 43,
#                      'new_deaths': 2,
#                      'new_positive': 43,
#                      'reinfections': 0}},
#  {'date': 20200318,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 4,
#                                            'new_deaths': 0,
#                                            'new_positive': 4,
#                                            'reinfections': 0},
#                 'NHS Borders': {'first_infections': 2,
#                                 'new_deaths': 0,
#                                 'new_positive': 2,
#                                 'reinfections': 0},
#                 'NHS Dumfries and Galloway': {'first_infections': 3,
#                                               'new_deaths': 0,
#                                               'new_positive': 3,
#                                               'reinfections': 0},
#                 'NHS Fife': {'first_infections': 2,
#                              'new_deaths': 0,
#                              'new_positive': 2,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 6,
#                                      'new_deaths': 0,
#                                      'new_positive': 6,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 1,
#                                  'new_deaths': 0,
#                                  'new_positive': 1,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 7,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 7,
#                                                   'reinfections': 0},
#                 'NHS Highland': {'first_infections': 1,
#                                  'new_deaths': 0,
#                                  'new_positive': 1,
#                                  'reinfections': 0},
#                 'NHS Lanarkshire': {'first_infections': 7,
#                                     'new_deaths': 0,
#                                     'new_positive': 7,
#                                     'reinfections': 0},
#                 'NHS Lothian': {'first_infections': 4,
#                                 'new_deaths': 0,
#                                 'new_positive': 4,
#                                 'reinfections': 0},
#                 'NHS Orkney': {},
#                 'NHS Shetland': {'first_infections': 0,
#                                  'new_deaths': 0,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Tayside': {'first_infections': 4,
#                                 'new_deaths': 0,
#                                 'new_positive': 4,
#                                 'reinfections': 0},
#                 'NHS Western Isles': {}},
#   'whole_scotland': {'first_infections': 41,
#                      'new_deaths': 0,
#                      'new_positive': 41,
#                      'reinfections': 0}},
#  {'date': 20200319,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 3,
#                                            'new_deaths': 0,
#                                            'new_positive': 3,
#                                            'reinfections': 0},
#                 'NHS Borders': {'first_infections': 1,
#                                 'new_deaths': 0,
#                                 'new_positive': 1,
#                                 'reinfections': 0},
#                 'NHS Dumfries and Galloway': {'first_infections': 5,
#                                               'new_deaths': 0,
#                                               'new_positive': 5,
#                                               'reinfections': 0},
#                 'NHS Fife': {'first_infections': 1,
#                              'new_deaths': 0,
#                              'new_positive': 1,
#                              'reinfections': 0},
#                 'NHS Forth Valley': {'first_infections': 2,
#                                      'new_deaths': 1,
#                                      'new_positive': 2,
#                                      'reinfections': 0},
#                 'NHS Grampian': {'first_infections': 0,
#                                  'new_deaths': 1,
#                                  'new_positive': 0,
#                                  'reinfections': 0},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 23,
#                                                   'new_deaths': 1,
#                                                   'new_positive': 23,
#                                                   'reinfections': 0},
#                 'NHS Highland': {'first_infections': 1,
#                                  'new_deaths': 0,
#                                  'new_positive': 1,
#                                  'reinfections': 0},
#                 'NHS Lanarkshire': {'first_infections': 5,
#                                     'new_deaths': 0,
#                                     'new_positive': 5,
#                                     'reinfections': 0},
#                 'NHS Lothian': {'first_infections': 5,
#                                 'new_deaths': 0,
#                                 'new_positive': 5,
# ...
#                 'NHS Grampian': {'first_infections': 1079,
#                                  'new_deaths': 1,
#                                  'new_positive': 1164,
#                                  'reinfections': 85},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 2153,
#                                                   'new_deaths': 2,
#                                                   'new_positive': 2463,
#                                                   'reinfections': 310},
#                 'NHS Highland': {'first_infections': 710,
#                                  'new_deaths': 1,
#                                  'new_positive': 764,
#                                  'reinfections': 54},
#                 'NHS Lanarkshire': {'first_infections': 1526,
#                                     'new_deaths': 3,
#                                     'new_positive': 1727,
#                                     'reinfections': 201},
#                 'NHS Lothian': {'first_infections': 1765,
#                                 'new_deaths': 2,
#                                 'new_positive': 1969,
#                                 'reinfections': 204},
#                 'NHS Orkney': {'first_infections': 32,
#                                'new_deaths': 0,
#                                'new_positive': 32,
#                                'reinfections': 0},
#                 'NHS Shetland': {'first_infections': 50,
#                                  'new_deaths': 0,
#                                  'new_positive': 50,
#                                  'reinfections': 0},
#                 'NHS Tayside': {'first_infections': 753,
#                                 'new_deaths': 2,
#                                 'new_positive': 812,
#                                 'reinfections': 59},
#                 'NHS Western Isles': {'first_infections': 119,
#                                       'new_deaths': 0,
#                                       'new_positive': 123,
#                                       'reinfections': 4}},
#   'whole_scotland': {'first_infections': 10895,
#                      'new_deaths': 14,
#                      'new_positive': 12113,
#                      'reinfections': 1218}},
#  {'date': 20220314,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 1165,
#                                            'new_deaths': 1,
#                                            'new_positive': 1332,
#                                            'reinfections': 167},
#                 'NHS Borders': {'first_infections': 251,
#                                 'new_deaths': 0,
#                                 'new_positive': 264,
#                                 'reinfections': 13},
#                 'NHS Dumfries and Galloway': {'first_infections': 349,
#                                               'new_deaths': 1,
#                                               'new_positive': 374,
#                                               'reinfections': 25},
#                 'NHS Fife': {'first_infections': 812,
#                              'new_deaths': 0,
#                              'new_positive': 911,
#                              'reinfections': 99},
#                 'NHS Forth Valley': {'first_infections': 872,
#                                      'new_deaths': 0,
#                                      'new_positive': 992,
#                                      'reinfections': 120},
#                 'NHS Grampian': {'first_infections': 1306,
#                                  'new_deaths': 1,
#                                  'new_positive': 1403,
#                                  'reinfections': 97},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 2809,
#                                                   'new_deaths': 4,
#                                                   'new_positive': 3262,
#                                                   'reinfections': 453},
#                 'NHS Highland': {'first_infections': 944,
#                                  'new_deaths': 2,
#                                  'new_positive': 1016,
#                                  'reinfections': 72},
#                 'NHS Lanarkshire': {'first_infections': 1748,
#                                     'new_deaths': 2,
#                                     'new_positive': 2031,
#                                     'reinfections': 283},
#                 'NHS Lothian': {'first_infections': 2140,
#                                 'new_deaths': 1,
#                                 'new_positive': 2362,
#                                 'reinfections': 222},
#                 'NHS Orkney': {'first_infections': 35,
#                                'new_deaths': 0,
#                                'new_positive': 38,
#                                'reinfections': 3},
#                 'NHS Shetland': {'first_infections': 57,
#                                  'new_deaths': 0,
#                                  'new_positive': 60,
#                                  'reinfections': 3},
#                 'NHS Tayside': {'first_infections': 963,
#                                 'new_deaths': 0,
#                                 'new_positive': 1041,
#                                 'reinfections': 78},
#                 'NHS Western Isles': {'first_infections': 135,
#                                       'new_deaths': 0,
#                                       'new_positive': 145,
#                                       'reinfections': 10}},
#   'whole_scotland': {'first_infections': 13586,
#                      'new_deaths': 12,
#                      'new_positive': 15231,
#                      'reinfections': 1645}},
#  {'date': 20220315,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 1198,
#                                            'new_deaths': 2,
#                                            'new_positive': 1372,
#                                            'reinfections': 174},
#                 'NHS Borders': {'first_infections': 265,
#                                 'new_deaths': 0,
#                                 'new_positive': 284,
#                                 'reinfections': 19},
#                 'NHS Dumfries and Galloway': {'first_infections': 314,
#                                               'new_deaths': 1,
#                                               'new_positive': 336,
#                                               'reinfections': 22},
#                 'NHS Fife': {'first_infections': 734,
#                              'new_deaths': 0,
#                              'new_positive': 815,
#                              'reinfections': 81},
#                 'NHS Forth Valley': {'first_infections': 848,
#                                      'new_deaths': 0,
#                                      'new_positive': 948,
#                                      'reinfections': 100},
#                 'NHS Grampian': {'first_infections': 1245,
#                                  'new_deaths': 2,
#                                  'new_positive': 1337,
#                                  'reinfections': 92},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 2693,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 3145,
#                                                   'reinfections': 452},
#                 'NHS Highland': {'first_infections': 970,
#                                  'new_deaths': 3,
#                                  'new_positive': 1026,
#                                  'reinfections': 56},
#                 'NHS Lanarkshire': {'first_infections': 1657,
#                                     'new_deaths': 0,
#                                     'new_positive': 1891,
#                                     'reinfections': 234},
#                 'NHS Lothian': {'first_infections': 2126,
#                                 'new_deaths': 0,
#                                 'new_positive': 2353,
#                                 'reinfections': 227},
#                 'NHS Orkney': {'first_infections': 34,
#                                'new_deaths': 0,
#                                'new_positive': 36,
#                                'reinfections': 2},
#                 'NHS Shetland': {'first_infections': 61,
#                                  'new_deaths': 0,
#                                  'new_positive': 62,
#                                  'reinfections': 1},
#                 'NHS Tayside': {'first_infections': 903,
#                                 'new_deaths': 0,
#                                 'new_positive': 959,
#                                 'reinfections': 56},
#                 'NHS Western Isles': {'first_infections': 129,
#                                       'new_deaths': 0,
#                                       'new_positive': 137,
#                                       'reinfections': 8}},
#   'whole_scotland': {'first_infections': 13177,
#                      'new_deaths': 8,
#                      'new_positive': 14701,
#                      'reinfections': 1524}},
#  {'date': 20220316,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 1071,
#                                            'new_deaths': 1,
#                                            'new_positive': 1202,
#                                            'reinfections': 131},
#                 'NHS Borders': {'first_infections': 217,
#                                 'new_deaths': 0,
#                                 'new_positive': 237,
#                                 'reinfections': 20},
#                 'NHS Dumfries and Galloway': {'first_infections': 287,
#                                               'new_deaths': 0,
#                                               'new_positive': 311,
#                                               'reinfections': 24},
#                 'NHS Fife': {'first_infections': 729,
#                              'new_deaths': 0,
#                              'new_positive': 815,
#                              'reinfections': 86},
#                 'NHS Forth Valley': {'first_infections': 758,
#                                      'new_deaths': 0,
#                                      'new_positive': 856,
#                                      'reinfections': 98},
#                 'NHS Grampian': {'first_infections': 1120,
#                                  'new_deaths': 0,
#                                  'new_positive': 1190,
#                                  'reinfections': 70},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 2442,
#                                                   'new_deaths': 2,
#                                                   'new_positive': 2778,
#                                                   'reinfections': 336},
#                 'NHS Highland': {'first_infections': 760,
#                                  'new_deaths': 1,
#                                  'new_positive': 810,
#                                  'reinfections': 50},
#                 'NHS Lanarkshire': {'first_infections': 1522,
#                                     'new_deaths': 0,
#                                     'new_positive': 1738,
#                                     'reinfections': 216},
#                 'NHS Lothian': {'first_infections': 1885,
#                                 'new_deaths': 0,
#                                 'new_positive': 2069,
#                                 'reinfections': 184},
#                 'NHS Orkney': {'first_infections': 27,
#                                'new_deaths': 0,
#                                'new_positive': 29,
#                                'reinfections': 2},
#                 'NHS Shetland': {'first_infections': 49,
#                                  'new_deaths': 0,
#                                  'new_positive': 51,
#                                  'reinfections': 2},
#                 'NHS Tayside': {'first_infections': 759,
#                                 'new_deaths': 0,
#                                 'new_positive': 828,
#                                 'reinfections': 69},
#                 'NHS Western Isles': {'first_infections': 102,
#                                       'new_deaths': 0,
#                                       'new_positive': 106,
#                                       'reinfections': 4}},
#   'whole_scotland': {'first_infections': 11728,
#                      'new_deaths': 4,
#                      'new_positive': 13020,
#                      'reinfections': 1292}},
#  {'date': 20220317,
#   'locations': {'NHS Ayrshire and Arran': {'first_infections': 545,
#                                            'new_deaths': 0,
#                                            'new_positive': 621,
#                                            'reinfections': 76},
#                 'NHS Borders': {'first_infections': 143,
#                                 'new_deaths': 0,
#                                 'new_positive': 155,
#                                 'reinfections': 12},
#                 'NHS Dumfries and Galloway': {'first_infections': 157,
#                                               'new_deaths': 0,
#                                               'new_positive': 170,
#                                               'reinfections': 13},
#                 'NHS Fife': {'first_infections': 432,
#                              'new_deaths': 0,
#                              'new_positive': 457,
#                              'reinfections': 25},
#                 'NHS Forth Valley': {'first_infections': 375,
#                                      'new_deaths': 0,
#                                      'new_positive': 407,
#                                      'reinfections': 32},
#                 'NHS Grampian': {'first_infections': 616,
#                                  'new_deaths': 0,
#                                  'new_positive': 655,
#                                  'reinfections': 39},
#                 'NHS Greater Glasgow and Clyde': {'first_infections': 1140,
#                                                   'new_deaths': 0,
#                                                   'new_positive': 1293,
#                                                   'reinfections': 153},
#                 'NHS Highland': {'first_infections': 424,
#                                  'new_deaths': 0,
#                                  'new_positive': 444,
#                                  'reinfections': 20},
#                 'NHS Lanarkshire': {'first_infections': 827,
#                                     'new_deaths': 1,
#                                     'new_positive': 971,
#                                     'reinfections': 144},
#                 'NHS Lothian': {'first_infections': 1000,
#                                 'new_deaths': 0,
#                                 'new_positive': 1102,
#                                 'reinfections': 102},
#                 'NHS Orkney': {'first_infections': 22,
#                                'new_deaths': 0,
#                                'new_positive': 23,
#                                'reinfections': 1},
#                 'NHS Shetland': {'first_infections': 35,
#                                  'new_deaths': 0,
#                                  'new_positive': 35,
#                                  'reinfections': 0},
#                 'NHS Tayside': {'first_infections': 415,
#                                 'new_deaths': 0,
#                                 'new_positive': 455,
#                                 'reinfections': 40},
#                 'NHS Western Isles': {'first_infections': 59,
#                                       'new_deaths': 0,
#                                       'new_positive': 64,
#                                       'reinfections': 5}},
#   'whole_scotland': {'first_infections': 6190,
#                      'new_deaths': 1,
#                      'new_positive': 6852,
#                      'reinfections': 662}}]
# "\n 'name': 'NHS Ayrshire and Arran',\n 'people': {'patients': 369670, 'staff': 9491}}\n --------------------------\n 'date': ALL,\n 'locations':'NHS Ayrshire and Arran',\n\n"

# %%
for i in covid_days:
    pp.pprint(i["date"])
# Out:
# 20200228
# 20200229
# 20200301
# 20200302
# 20200303
# 20200304
# 20200305
# 20200306
# 20200307
# 20200308
# 20200309
# 20200310
# 20200311
# 20200312
# 20200313
# 20200314
# 20200315
# 20200316
# 20200317
# 20200318
# 20200319
# 20200320
# 20200321
# 20200322
# 20200323
# 20200324
# 20200325
# 20200326
# 20200327
# 20200328
# 20200329
# 20200330
# 20200331
# 20200401
# 20200402
# 20200403
# 20200404
# 20200405
# 20200406
# 20200407
# 20200408
# 20200409
# 20200410
# 20200411
# 20200412
# 20200413
# 20200414
# 20200415
# 20200416
# 20200417
# 20200418
# 20200419
# 20200420
# 20200421
# 20200422
# 20200423
# 20200424
# 20200425
# 20200426
# 20200427
# 20200428
# 20200429
# 20200430
# 20200501
# 20200502
# 20200503
# 20200504
# 20200505
# 20200506
# 20200507
# 20200508
# 20200509
# 20200510
# 20200511
# 20200512
# 20200513
# 20200514
# 20200515
# 20200516
# 20200517
# 20200518
# 20200519
# 20200520
# 20200521
# 20200522
# 20200523
# 20200524
# 20200525
# 20200526
# 20200527
# 20200528
# 20200529
# 20200530
# 20200531
# 20200601
# 20200602
# 20200603
# 20200604
# 20200605
# 20200606
# 20200607
# 20200608
# 20200609
# 20200610
# 20200611
# 20200612
# 20200613
# 20200614
# 20200615
# 20200616
# 20200617
# 20200618
# 20200619
# 20200620
# 20200621
# 20200622
# 20200623
# 20200624
# 20200625
# 20200626
# 20200627
# 20200628
# 20200629
# 20200630
# 20200701
# 20200702
# 20200703
# 20200704
# 20200705
# 20200706
# 20200707
# 20200708
# 20200709
# 20200710
# 20200711
# 20200712
# 20200713
# 20200714
# 20200715
# 20200716
# 20200717
# 20200718
# 20200719
# 20200720
# 20200721
# 20200722
# 20200723
# 20200724
# 20200725
# 20200726
# 20200727
# 20200728
# 20200729
# 20200730
# 20200731
# 20200801
# 20200802
# 20200803
# 20200804
# 20200805
# 20200806
# 20200807
# 20200808
# 20200809
# 20200810
# 20200811
# 20200812
# 20200813
# 20200814
# 20200815
# 20200816
# 20200817
# 20200818
# 20200819
# 20200820
# 20200821
# 20200822
# 20200823
# 20200824
# 20200825
# 20200826
# 20200827
# 20200828
# 20200829
# 20200830
# 20200831
# 20200901
# 20200902
# 20200903
# 20200904
# 20200905
# 20200906
# 20200907
# 20200908
# 20200909
# 20200910
# 20200911
# 20200912
# 20200913
# 20200914
# 20200915
# 20200916
# 20200917
# 20200918
# 20200919
# 20200920
# 20200921
# 20200922
# 20200923
# 20200924
# 20200925
# 20200926
# 20200927
# 20200928
# 20200929
# 20200930
# 20201001
# 20201002
# 20201003
# 20201004
# 20201005
# 20201006
# 20201007
# 20201008
# 20201009
# 20201010
# 20201011
# 20201012
# 20201013
# 20201014
# 20201015
# 20201016
# 20201017
# 20201018
# 20201019
# 20201020
# 20201021
# 20201022
# 20201023
# 20201024
# 20201025
# 20201026
# 20201027
# 20201028
# 20201029
# 20201030
# 20201031
# 20201101
# 20201102
# 20201103
# 20201104
# 20201105
# 20201106
# 20201107
# 20201108
# 20201109
# 20201110
# 20201111
# 20201112
# 20201113
# 20201114
# 20201115
# 20201116
# 20201117
# 20201118
# 20201119
# 20201120
# 20201121
# 20201122
# 20201123
# 20201124
# 20201125
# 20201126
# 20201127
# 20201128
# 20201129
# 20201130
# 20201201
# 20201202
# 20201203
# 20201204
# 20201205
# 20201206
# 20201207
# 20201208
# 20201209
# 20201210
# 20201211
# 20201212
# 20201213
# 20201214
# 20201215
# 20201216
# 20201217
# 20201218
# 20201219
# 20201220
# 20201221
# 20201222
# 20201223
# 20201224
# 20201225
# 20201226
# 20201227
# 20201228
# 20201229
# 20201230
# 20201231
# 20210101
# 20210102
# 20210103
# 20210104
# 20210105
# 20210106
# 20210107
# 20210108
# 20210109
# 20210110
# 20210111
# 20210112
# 20210113
# 20210114
# 20210115
# 20210116
# 20210117
# 20210118
# 20210119
# 20210120
# 20210121
# 20210122
# 20210123
# 20210124
# 20210125
# 20210126
# 20210127
# 20210128
# 20210129
# 20210130
# 20210131
# 20210201
# 20210202
# 20210203
# 20210204
# 20210205
# 20210206
# 20210207
# 20210208
# 20210209
# 20210210
# 20210211
# 20210212
# 20210213
# 20210214
# 20210215
# 20210216
# 20210217
# 20210218
# 20210219
# 20210220
# 20210221
# 20210222
# 20210223
# 20210224
# 20210225
# 20210226
# 20210227
# 20210228
# 20210301
# 20210302
# 20210303
# 20210304
# 20210305
# 20210306
# 20210307
# 20210308
# 20210309
# 20210310
# 20210311
# 20210312
# 20210313
# 20210314
# 20210315
# 20210316
# 20210317
# 20210318
# 20210319
# 20210320
# 20210321
# 20210322
# 20210323
# 20210324
# 20210325
# 20210326
# 20210327
# 20210328
# 20210329
# 20210330
# 20210331
# 20210401
# 20210402
# 20210403
# 20210404
# 20210405
# 20210406
# 20210407
# 20210408
# 20210409
# 20210410
# 20210411
# 20210412
# 20210413
# 20210414
# 20210415
# 20210416
# 20210417
# 20210418
# 20210419
# 20210420
# 20210421
# 20210422
# 20210423
# 20210424
# 20210425
# 20210426
# 20210427
# 20210428
# 20210429
# 20210430
# 20210501
# 20210502
# 20210503
# 20210504
# 20210505
# 20210506
# 20210507
# 20210508
# 20210509
# 20210510
# 20210511
# 20210512
# 20210513
# 20210514
# 20210515
# 20210516
# 20210517
# 20210518
# 20210519
# 20210520
# 20210521
# 20210522
# 20210523
# 20210524
# 20210525
# 20210526
# 20210527
# 20210528
# 20210529
# 20210530
# 20210531
# 20210601
# 20210602
# 20210603
# 20210604
# 20210605
# 20210606
# 20210607
# 20210608
# 20210609
# 20210610
# 20210611
# 20210612
# 20210613
# 20210614
# 20210615
# 20210616
# 20210617
# 20210618
# 20210619
# 20210620
# 20210621
# 20210622
# 20210623
# 20210624
# 20210625
# 20210626
# 20210627
# 20210628
# 20210629
# 20210630
# 20210701
# 20210702
# 20210703
# 20210704
# 20210705
# 20210706
# 20210707
# 20210708
# 20210709
# 20210710
# 20210711
# 20210712
# 20210713
# 20210714
# 20210715
# 20210716
# 20210717
# 20210718
# 20210719
# 20210720
# 20210721
# 20210722
# 20210723
# 20210724
# 20210725
# 20210726
# 20210727
# 20210728
# 20210729
# 20210730
# 20210731
# 20210801
# 20210802
# 20210803
# 20210804
# 20210805
# 20210806
# 20210807
# 20210808
# 20210809
# 20210810
# 20210811
# 20210812
# 20210813
# 20210814
# 20210815
# 20210816
# 20210817
# 20210818
# 20210819
# 20210820
# 20210821
# 20210822
# 20210823
# 20210824
# 20210825
# 20210826
# 20210827
# 20210828
# 20210829
# 20210830
# 20210831
# 20210901
# 20210902
# 20210903
# 20210904
# 20210905
# 20210906
# 20210907
# 20210908
# 20210909
# 20210910
# 20210911
# 20210912
# 20210913
# 20210914
# 20210915
# 20210916
# 20210917
# 20210918
# 20210919
# 20210920
# 20210921
# 20210922
# 20210923
# 20210924
# 20210925
# 20210926
# 20210927
# 20210928
# 20210929
# 20210930
# 20211001
# 20211002
# 20211003
# 20211004
# 20211005
# 20211006
# 20211007
# 20211008
# 20211009
# 20211010
# 20211011
# 20211012
# 20211013
# 20211014
# 20211015
# 20211016
# 20211017
# 20211018
# 20211019
# 20211020
# 20211021
# 20211022
# 20211023
# 20211024
# 20211025
# 20211026
# 20211027
# 20211028
# 20211029
# 20211030
# 20211031
# 20211101
# 20211102
# 20211103
# 20211104
# 20211105
# 20211106
# 20211107
# 20211108
# 20211109
# 20211110
# 20211111
# 20211112
# 20211113
# 20211114
# 20211115
# 20211116
# 20211117
# 20211118
# 20211119
# 20211120
# 20211121
# 20211122
# 20211123
# 20211124
# 20211125
# 20211126
# 20211127
# 20211128
# 20211129
# 20211130
# 20211201
# 20211202
# 20211203
# 20211204
# 20211205
# 20211206
# 20211207
# 20211208
# 20211209
# 20211210
# 20211211
# 20211212
# 20211213
# 20211214
# 20211215
# 20211216
# 20211217
# 20211218
# 20211219
# 20211220
# 20211221
# 20211222
# 20211223
# 20211224
# 20211225
# 20211226
# 20211227
# 20211228
# 20211229
# 20211230
# 20211231
# 20220101
# 20220102
# 20220103
# 20220104
# 20220105
# 20220106
# 20220107
# 20220108
# 20220109
# 20220110
# 20220111
# 20220112
# 20220113
# 20220114
# 20220115
# 20220116
# 20220117
# 20220118
# 20220119
# 20220120
# 20220121
# 20220122
# 20220123
# 20220124
# 20220125
# 20220126
# 20220127
# 20220128
# 20220129
# 20220130
# 20220131
# 20220201
# 20220202
# 20220203
# 20220204
# 20220205
# 20220206
# 20220207
# 20220208
# 20220209
# 20220210
# 20220211
# 20220212
# 20220213
# 20220214
# 20220215
# 20220216
# 20220217
# 20220218
# 20220219
# 20220220
# 20220221
# 20220222
# 20220223
# 20220224
# 20220225
# 20220226
# 20220227
# 20220228
# 20220301
# 20220302
# 20220303
# 20220304
# 20220305
# 20220306
# 20220307
# 20220308
# 20220309
# 20220310
# 20220311
# 20220312
# 20220313
# 20220314
# 20220315
# 20220316
# 20220317

# %%
import matplotlib.pyplot as plt

# Extract date and first_infections data
dates = [str(entry["date"]) for entry in covid_days]
first_infections = [entry["whole_scotland"]["first_infections"] for entry in covid_days]

pp.pprint(dates[:5])
pp.pprint(first_infections)


# Plotting
plt.figure(figsize=(10, 4))
plt.plot(dates, first_infections, marker="o", linestyle="-", color="b")
plt.xticks(dates[::20], rotation=45)
plt.xlabel("Date")
plt.ylabel("First Infections")
plt.title("First Infections Over Time in Scotland")
plt.tight_layout()
plt.grid(True, which="both", linestyle="--", linewidth=0.5)
plt.show()
# Out:
# ['20200228', '20200229', '20200301', '20200302', '20200303']
# [1,
#  0,
#  2,
#  1,
#  3,
#  6,
#  2,
#  6,
#  6,
#  3,
#  16,
#  21,
#  25,
#  38,
#  48,
#  19,
#  12,
#  21,
#  43,
#  41,
#  50,
#  84,
#  67,
#  74,
#  138,
#  167,
#  188,
#  223,
#  274,
#  204,
#  197,
#  317,
#  341,
#  389,
#  351,
#  381,
#  261,
#  225,
#  404,
#  352,
#  343,
#  304,
#  329,
#  185,
#  220,
#  359,
#  346,
#  331,
#  428,
#  394,
#  264,
#  159,
#  348,
#  400,
#  340,
#  314,
#  306,
#  184,
#  171,
#  434,
#  383,
#  431,
#  337,
#  375,
#  222,
#  188,
#  329,
#  288,
#  307,
#  297,
#  258,
#  180,
#  153,
#  265,
#  230,
#  198,
#  211,
#  151,
#  103,
#  93,
#  141,
#  182,
#  121,
#  111,
#  91,
#  50,
#  53,
#  96,
#  478,
#  66,
#  55,
#  30,
#  40,
#  23,
#  38,
#  46,
#  34,
#  35,
#  24,
#  22,
#  17,
#  18,
#  27,
#  29,
#  21,
#  30,
#  22,
#  13,
#  21,
#  17,
#  33,
#  14,
#  24,
#  6,
#  9,
#  10,
#  20,
#  8,
#  19,
#  6,
#  4,
#  3,
#  14,
#  8,
#  11,
#  13,
#  6,
#  5,
#  2,
#  8,
#  11,
#  10,
#  8,
#  12,
#  9,
#  2,
#  18,
#  10,
#  16,
#  21,
#  8,
#  13,
#  17,
#  13,
#  19,
#  16,
#  23,
#  11,
#  3,
#  7,
#  13,
#  22,
#  28,
#  27,
#  21,
#  22,
#  19,
#  60,
#  57,
#  64,
#  62,
#  46,
#  27,
#  26,
#  57,
#  64,
#  48,
#  52,
#  50,
#  20,
#  30,
#  72,
#  77,
#  91,
#  140,
#  90,
#  47,
#  65,
#  60,
#  69,
#  97,
#  99,
#  104,
#  95,
#  102,
#  144,
#  199,
#  191,
#  201,
#  171,
#  136,
#  153,
#  167,
#  102,
#  222,
#  216,
#  209,
#  207,
#  166,
#  177,
#  227,
#  268,
#  254,
#  269,
#  232,
#  315,
#  454,
#  493,
#  567,
#  715,
#  578,
#  434,
#  358,
#  623,
#  659,
#  794,
#  778,
#  817,
#  695,
#  742,
#  1099,
#  1190,
#  1253,
#  1169,
#  1093,
#  941,
#  959,
#  1354,
#  1421,
#  1292,
#  1292,
#  1252,
#  855,
#  833,
#  1359,
#  1690,
#  1579,
#  1491,
#  1280,
#  953,
#  939,
#  1345,
#  1305,
#  1266,
#  1098,
#  1088,
#  742,
#  969,
#  1474,
#  1392,
#  1301,
#  1295,
#  1134,
#  842,
#  873,
#  1296,
#  1287,
#  1247,
#  1195,
#  1054,
#  903,
#  817,
#  1277,
#  1225,
#  1113,
#  984,
#  860,
#  764,
#  709,
#  1156,
#  994,
#  932,
#  804,
#  738,
#  572,
#  558,
#  973,
#  932,
#  951,
#  805,
#  649,
#  666,
#  643,
#  955,
#  1046,
#  1008,
#  902,
#  872,
#  681,
#  719,
#  1081,
#  1030,
#  1028,
#  909,
#  920,
#  748,
#  812,
#  1304,
#  1327,
#  1311,
#  1017,
#  515,
#  1050,
#  1681,
#  1804,
#  3130,
#  2963,
#  2374,
#  1159,
#  2211,
#  2218,
#  2375,
#  3050,
#  2543,
#  2196,
#  1823,
#  1497,
#  1423,
#  2088,
#  1977,
#  1712,
#  1620,
#  1535,
#  1176,
#  1199,
#  1735,
#  1546,
#  1572,
#  1240,
#  1228,
#  936,
#  857,
#  1318,
#  1177,
#  1112,
#  1113,
#  961,
#  779,
#  808,
#  1095,
#  1049,
#  930,
#  899,
#  935,
#  706,
#  654,
#  991,
#  758,
#  843,
#  842,
#  901,
#  542,
#  681,
#  963,
#  912,
#  825,
#  878,
#  890,
#  660,
#  609,
#  787,
#  693,
#  699,
#  628,
#  522,
#  414,
#  426,
#  547,
#  518,
#  495,
#  558,
#  465,
#  479,
#  433,
#  588,
#  653,
#  622,
#  662,
#  584,
#  464,
#  443,
#  688,
#  572,
#  597,
#  552,
#  542,
#  458,
#  463,
#  680,
#  603,
#  541,
#  573,
#  474,
#  386,
#  357,
#  514,
#  394,
#  394,
#  413,
#  353,
#  280,
#  254,
#  293,
#  356,
#  282,
#  282,
#  266,
#  227,
#  212,
#  260,
#  261,
#  212,
#  198,
#  222,
#  202,
#  175,
#  264,
#  242,
#  237,
#  231,
#  188,
#  150,
#  109,
#  195,
#  195,
#  193,
#  174,
#  172,
#  126,
#  121,
#  162,
#  196,
#  222,
#  218,
#  203,
#  185,
#  210,
#  329,
#  283,
#  298,
#  314,
#  291,
#  228,
#  231,
#  361,
#  417,
#  409,
#  381,
#  360,
#  291,
#  324,
#  496,
#  504,
#  628,
#  552,
#  548,
#  435,
#  486,
#  601,
#  773,
#  959,
#  949,
#  822,
#  606,
#  677,
#  953,
#  1026,
#  1056,
#  1040,
#  865,
#  706,
#  855,
#  1130,
#  1279,
#  1265,
#  1164,
#  1231,
#  997,
#  1548,
#  3019,
#  3243,
#  2891,
#  2947,
#  2619,
#  2292,
#  2511,
#  3922,
#  3873,
#  3907,
#  3429,
#  3079,
#  2509,
#  2407,
#  3378,
#  3091,
#  2896,
#  2729,
#  2382,
#  1812,
#  1881,
#  2577,
#  2444,
#  2194,
#  1963,
#  1749,
#  1400,
#  1385,
#  1908,
#  1598,
#  1573,
#  1378,
#  1277,
#  954,
#  942,
#  1372,
#  1353,
#  1286,
#  1171,
#  1034,
#  769,
#  873,
#  1322,
#  1366,
#  1293,
#  1330,
#  1256,
#  941,
#  1040,
#  1489,
#  1518,
#  1567,
#  1391,
#  1523,
#  1471,
#  1628,
#  2746,
#  3362,
#  3704,
#  3711,
#  3421,
#  3030,
#  3646,
#  5518,
#  5597,
#  6824,
#  7223,
#  6020,
#  4736,
#  4431,
#  6519,
#  6957,
#  7491,
#  7526,
#  6130,
#  4986,
#  4900,
#  7086,
#  6658,
#  6209,
#  5516,
#  4757,
#  3616,
#  3353,
#  5053,
#  4745,
#  4050,
#  3556,
#  3353,
#  2604,
#  2781,
#  3991,
#  3780,
#  3488,
#  3096,
#  2698,
#  2125,
#  2135,
#  3112,
#  3175,
#  2586,
#  2361,
#  2040,
#  1860,
#  1979,
#  2945,
#  2831,
#  2638,
#  2593,
#  2279,
#  2129,
#  1879,
#  2813,
#  2621,
#  2631,
#  2673,
#  2568,
#  2149,
#  2299,
#  2950,
#  2764,
#  2840,
#  2536,
#  2444,
#  2132,
#  2319,
#  3296,
#  2917,
#  2651,
#  2497,
#  2547,
#  2029,
#  2071,
#  3299,
#  3043,
#  2983,
#  2797,
#  2772,
#  2217,
#  2301,
#  3825,
#  3458,
#  3296,
#  3217,
#  2856,
#  2322,
#  2423,
#  3643,
#  3280,
#  3318,
#  2992,
#  2785,
#  2214,
#  2175,
#  3161,
#  2882,
#  2896,
#  2492,
#  2236,
#  1884,
#  2331,
#  3457,
#  3295,
#  3094,
#  2928,
#  2641,
#  2123,
#  2485,
#  3766,
#  3720,
#  4125,
#  3963,
#  3722,
#  3232,
#  3327,
#  5602,
#  6259,
#  6845,
#  6269,
#  5600,
#  4918,
#  5273,
#  8090,
#  9737,
#  10902,
#  11326,
#  8942,
#  4517,
#  6976,
#  17293,
#  18264,
#  21426,
#  20168,
#  16158,
#  6792,
#  14302,
#  17744,
#  17859,
#  20596,
#  12723,
#  8385,
#  6679,
#  7124,
#  8634,
#  7614,
#  7106,
#  6762,
#  6034,
#  5348,
#  6575,
#  8411,
#  7857,
#  7266,
#  6558,
#  6184,
#  5674,
#  6757,
#  8745,
#  7772,
#  7550,
#  6534,
#  6098,
#  5067,
#  6393,
#  8117,
#  7694,
#  7287,
#  6544,
#  5496,
#  4862,
#  5583,
#  7082,
#  7828,
#  7489,
#  6178,
#  5623,
#  4973,
#  5589,
#  7158,
#  7493,
#  7230,
#  6532,
#  5417,
#  5017,
#  5799,
#  7429,
#  7027,
#  6558,
#  5627,
#  5453,
#  4943,
#  5990,
#  8412,
#  8493,
#  8484,
#  8190,
#  7313,
#  7022,
#  9112,
#  11970,
#  12253,
#  12555,
#  11248,
#  10350,
#  9179,
#  10895,
#  13586,
#  13177,
#  11728,
#  6190]

# %%
#  first graph:
## y: first-infection [whole time period(20200228-20220228)]
## x:location
total_infections = {location: 0 for location in covid_days[0]["locations"]}

for entry in covid_days:
    # Check if the date is within the desired range
    if 20200228 <= entry["date"] <= 20220228:
        for location, values in entry["locations"].items():
            total_infections[location] += values.get("first_infections", 0)

print(total_infections)

import matplotlib.pyplot as plt

# Extracting keys and values from the dictionary
locations = list(total_infections.keys())
values = list(total_infections.values())

# Plotting
plt.figure(figsize=(8, 5))
plt.bar(locations, values, color="skyblue")
plt.xlabel("NHS Locations")
plt.ylabel("Number of Infections")
plt.title("Number of Infections by NHS Location")
plt.xticks(rotation=45, ha="right")  # Rotating x-axis labels for better visibility
plt.tight_layout()
plt.show()
# Out:
# {'NHS Ayrshire and Arran': 96511, 'NHS Borders': 22335, 'NHS Dumfries and Galloway': 31799, 'NHS Fife': 94122, 'NHS Forth Valley': 81832, 'NHS Grampian': 128664, 'NHS Greater Glasgow and Clyde': 343488, 'NHS Highland': 60890, 'NHS Lanarkshire': 202343, 'NHS Lothian': 237180, 'NHS Orkney': 3479, 'NHS Shetland': 4002, 'NHS Tayside': 101381, 'NHS Western Isles': 3391}

# %%
#  Second graph:
## y: total-death [whole time period(20200228-20220228)]
## x:location
total_death = {location: 0 for location in covid_days[0]["locations"]}

for entry in covid_days:
    # Check if the date is within the desired range
    if 20200228 <= entry["date"] <= 20220228:
        for location, values in entry["locations"].items():
            total_death[location] += values.get("new_deaths", 0)

print(total_death)

import matplotlib.pyplot as plt

# Extracting keys and values from the dictionary
locations = list(total_death.keys())
values = list(total_death.values())

# Plotting
plt.figure(figsize=(8, 5))
plt.bar(locations, values, color="skyblue")
plt.xlabel("NHS Locations")
plt.ylabel("Number of Deaths")
plt.title("Number of Deaths by NHS Location")
plt.xticks(rotation=45, ha="right")  # Rotating x-axis labels for better visibility
plt.tight_layout()
plt.show()
# Out:
# {'NHS Ayrshire and Arran': 1040, 'NHS Borders': 168, 'NHS Dumfries and Galloway': 221, 'NHS Fife': 626, 'NHS Forth Valley': 647, 'NHS Grampian': 655, 'NHS Greater Glasgow and Clyde': 3005, 'NHS Highland': 288, 'NHS Lanarkshire': 1753, 'NHS Lothian': 1537, 'NHS Orkney': 13, 'NHS Shetland': 14, 'NHS Tayside': 873, 'NHS Western Isles': 25}

# %%
#  Second graph:
## y: total-death/total-patients [whole time period(20200228-20220228)]
## x:location
total_death = {location: 0 for location in covid_days[0]["locations"]}

for entry in covid_days:
    # Check if the date is within the desired range
    if 20200228 <= entry["date"] <= 20220228:
        for location, values in entry["locations"].items():
            total_death[location] += values.get("new_deaths", 0)

print(total_death)

import matplotlib.pyplot as plt

# Extracting keys and values from the dictionary
locations = list(total_death.keys())
values = list(total_death.values())

# Plotting
plt.figure(figsize=(8, 5))
plt.bar(locations, values, color="skyblue")
plt.xlabel("NHS Locations")
plt.ylabel("Number of Deaths")
plt.title("Number of Deaths by NHS Location")
plt.xticks(rotation=45, ha="right")  # Rotating x-axis labels for better visibility
plt.tight_layout()
plt.show()
# Out:
# {'NHS Ayrshire and Arran': 1040, 'NHS Borders': 168, 'NHS Dumfries and Galloway': 221, 'NHS Fife': 626, 'NHS Forth Valley': 647, 'NHS Grampian': 655, 'NHS Greater Glasgow and Clyde': 3005, 'NHS Highland': 288, 'NHS Lanarkshire': 1753, 'NHS Lothian': 1537, 'NHS Orkney': 13, 'NHS Shetland': 14, 'NHS Tayside': 873, 'NHS Western Isles': 25}

# %%
for i in boards_info:
    pp.pprint(i)
# Out:
# {'budget_millions': {'2020': 762, '2021': 775, '2022': 807},
#  'geographic': {'area_km_2': 2924,
#                 'areas_covered': 'East Ayrshire, North Ayrshire, South '
#                                  'Ayrshire'},
#  'name': 'NHS Ayrshire and Arran',
#  'people': {'patients': 369670, 'staff': 9491}}
# {'budget_millions': {'2020': 220, '2021': 223, '2022': 235},
#  'geographic': {'area_km_2': 4732, 'areas_covered': 'Scottish Borders'},
#  'name': 'NHS Borders',
#  'people': {'patients': 115270, 'staff': 2627}}
# {'budget_millions': {'2020': 316, '2021': 321, '2022': 334},
#  'geographic': {'area_km_2': 6216, 'areas_covered': 'Dumfries and Galloway'},
#  'name': 'NHS Dumfries and Galloway',
#  'people': {'patients': 148790, 'staff': 3832}}
# {'budget_millions': {'2020': 702, '2021': 713, '2022': 749},
#  'geographic': {'area_km_2': 1235, 'areas_covered': 'Fife'},
#  'name': 'NHS Fife',
#  'people': {'patients': 371910, 'staff': 7683}}
# {'budget_millions': {'2020': 559, '2021': 569, '2022': 598},
#  'geographic': {'area_km_2': 2643,
#                 'areas_covered': 'Clackmannanshire, Falkirk, Stirling'},
#  'name': 'NHS Forth Valley',
#  'people': {'patients': 306070, 'staff': 5419}}
# {'budget_millions': {'2020': 1014, '2021': 1028, '2022': 1072},
#  'geographic': {'area_km_2': 8736,
#                 'areas_covered': 'Aberdeenshire, City of Aberdeen, Moray'},
#  'name': 'NHS Grampian',
#  'people': {'patients': 584550, 'staff': 12952}}
# {'budget_millions': {'2020': 2365, '2021': 2398, '2022': 2504},
#  'geographic': {'area_km_2': 1106,
#                 'areas_covered': 'City of Glasgow, East Dunbartonshire, East '
#                                  'Renfrewshire, Inverclyde, Renfrewshire, West '
#                                  'Dunbartonshire'},
#  'name': 'NHS Greater Glasgow and Clyde',
#  'people': {'patients': 1174980, 'staff': 38000}}
# {'budget_millions': {'2020': 666, '2021': 692, '2022': 726},
#  'geographic': {'area_km_2': 32566,
#                 'areas_covered': 'Highland, Argyll and Bute'},
#  'name': 'NHS Highland',
#  'people': {'patients': 321800, 'staff': 8564}}
# {'budget_millions': {'2020': 1268, '2021': 1286, '2022': 1347},
#  'geographic': {'area_km_2': 4732,
#                 'areas_covered': 'North Lanarkshire, South Lanarkshire'},
#  'name': 'NHS Lanarkshire',
#  'people': {'patients': 659200, 'staff': 11641}}
# {'budget_millions': {'2020': 1540, '2021': 1570, '2022': 1639},
#  'geographic': {'area_km_2': 1471,
#                 'areas_covered': 'City of Edinburgh, East Lothian, Midlothian, '
#                                  'West Lothian'},
#  'name': 'NHS Lothian',
#  'people': {'patients': 897770, 'staff': 21921}}
# {'budget_millions': {'2020': 53, '2021': 55, '2022': 57},
#  'geographic': {'area_km_2': 989, 'areas_covered': 'Orkney Islands'},
#  'name': 'NHS Orkney',
#  'people': {'patients': 22190, 'staff': 565}}
# {'budget_millions': {'2020': 54, '2021': 55, '2022': 57},
#  'geographic': {'area_km_2': 1467, 'areas_covered': 'Shetland Islands'},
#  'name': 'NHS Shetland',
#  'people': {'patients': 22990, 'staff': 598}}
# {'budget_millions': {'2020': 809, '2021': 820, '2022': 857},
#  'geographic': {'area_km_2': 7527,
#                 'areas_covered': 'Angus, City of Dundee, Perth and Kinross'},
#  'name': 'NHS Tayside',
#  'people': {'patients': 416080, 'staff': 11460}}
# {'budget_millions': {'2020': 80, '2021': 81, '2022': 85},
#  'geographic': {'area_km_2': 3070, 'areas_covered': 'Outer Hebrides'},
#  'name': 'NHS Western Isles',
#  'people': {'patients': 26830, 'staff': 821}}

# %% [markdown]
# ### Third dataset: Cancer waiting times:
#
# cancer_waiting_times is a json dataset with numbers on how many cancer patients were treated within 1 month of being diagnosed.
#
# You will find in it information about year and quarter of when data was gathered, cancer type, numbers of patients, NHS board*
#
# *(board comes as an id. You can look it up in the variable boards_code_lookup)
#
# For more information about the data you can lookup the source:
#
# https://www.opendata.nhs.scot/dataset/cancer-waiting-times/resource/58527343-a930-4058-bf9e-3c6e5cb04010?inner_span=True

# %%
pp.pprint(cancer_waiting_times[0])
# Out:
# {'Board_id': 'S08000015',
#  'Cancer_types': {'Breast': {'diagnosed': 88, 'treated': 88},
#                   'Cervical': {'diagnosed': 5, 'treated': 5},
#                   'Colorectal': {'diagnosed': 56, 'treated': 55},
#                   'Head & Neck': {'diagnosed': 17, 'treated': 16},
#                   'Lung': {'diagnosed': 6, 'treated': 6},
#                   'Lymphoma': {'diagnosed': 25, 'treated': 25},
#                   'Melanoma': {'diagnosed': 17, 'treated': 17},
#                   'Ovarian': {'diagnosed': 12, 'treated': 12},
#                   'Upper GI': {'diagnosed': 42, 'treated': 42},
#                   'Urological': {'diagnosed': 66, 'treated': 64}},
#  'Quarter': 1,
#  'Year': 2012}

# %%
pp.pprint(boards_code_lookup)
# Out:
# {'S08000015': 'NHS Ayrshire and Arran',
#  'S08000016': 'NHS Borders',
#  'S08000017': 'NHS Dumfries and Galloway',
#  'S08000018': 'NHS Fife',
#  'S08000019': 'NHS Forth Valley',
#  'S08000020': 'NHS Grampian',
#  'S08000021': 'NHS Greater Glasgow and Clyde',
#  'S08000022': 'NHS Highland',
#  'S08000023': 'NHS Lanarkshire',
#  'S08000024': 'NHS Lothian',
#  'S08000025': 'NHS Orkney',
#  'S08000026': 'NHS Shetland',
#  'S08000027': 'NHS Tayside',
#  'S08000028': 'NHS Western Isles',
#  'S08000029': 'NHS Fife',
#  'S08000030': 'NHS Tayside',
#  'S08000031': 'NHS Greater Glasgow and Clyde',
#  'S08000032': 'NHS Lanarkshire'}

# %% [markdown]
# # Your submission goes below:

# %%
# You can put your code here and below. Feel free to add more cells with a [+] button

# %%
# your graph could be generated here. Please make it very clear which graph is the part of your mini-report

# %% [markdown]
# ### Your minireport can be here (within 200 words)
#
# Click this cell to edit it. Run it with Shift+Enter to see how it will look when 'interpreted'.
